# %% [markdown]
# <a href="https://colab.research.google.com/github/Agarwal-Mahima-3/First/blob/main/A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/Telecom Dataset (1).csv')

# %%
data.head()
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
# 2  BAB657J   no   yes      no      no   840   720      2      1   4   2
# 3  BBD456K   no   yes     yes      no  1280  1120      5      3   6   2
# 4  CCP761U   no   yes     yes      no  1280  1080      4      3   6   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price
# 0        8     2800    2      7     320   3297
# 1        8     3000    2      7     280   4500
# 2        8     3300    2      7     400   4898
# 3       32     3000    2      3     300   6900
# 4       16     3000    2      3     210   5600

# %%
data.shape
# Out:
# (50, 17)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
data.columns
# Out:
# Index(['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h',
#        'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight',
#        'Price'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PID      50 non-null     object
#  1   Blue     50 non-null     object
#  2   Wi_Fi    50 non-null     object
#  3   Tch_Scr  50 non-null     object
#  4   Ext_Mem  50 non-null     object
#  5   Px_h     50 non-null     int64
#  6   Px_w     50 non-null     int64
#  7   Scr_h    50 non-null     int64
#  8   Scr_w    50 non-null     int64
#  9   PC       50 non-null     int64
#  10  FC       50 non-null     int64
#  11  Int_Mem  50 non-null     int64
#  12  Bty_Pwr  50 non-null     int64
#  13  RAM      50 non-null     int64
#  14  Depth    50 non-null     int64
#  15  Weight   50 non-null     int64
#  16  Price    50 non-null     int64
# dtypes: int64(12), object(5)
# memory usage: 6.8+ KB

# %%
# Get the feature names of the dataframe
object = pd.Series(
    index=[ 'Blue', 'Wi_Fi' ,'Tch_Scr','Ext_Mem' ],
    data=data.dtypes,
    name='dtypes'

)
print(object)
# Out:
# Blue       object
# Wi_Fi      object
# Tch_Scr    object
# Ext_Mem    object
# Name: dtypes, dtype: object

# %%
blue_condition = data['Blue'] == 'yes'
wifi_condition = data['Wi_Fi'] == 'yes'
touch_screen_condition = data['Tch_Scr'] == 'yes'
external_memory_condition = data['Ext_Mem'] == 'yes'

# %%
con1 = blue_condition & wifi_condition & touch_screen_condition & external_memory_condition

# %%
filtered_data = data[con1]
display(filtered_data)
# Out:
#         PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 8   DGS789M  yes   yes     yes     yes  2580  1920      6      3  32  16
# 9   ENG897N  yes   yes     yes     yes  2580  1980      5      3  64  32
# 10  EOP657N  yes   yes     yes     yes  2580  1920      6      3  32  16
# 11  ELS333L  yes   yes     yes     yes  2580  1920      8      6  64  32
# 14  NBN329S  yes   yes     yes     yes  2380  1820      5      3  16   8
# 27  SFK567Y  yes   yes     yes     yes  2580  2120      8      6  64  16
# 28  SSD000L  yes   yes     yes     yes  2580  2120      8      6  64  32
# 30  TVF078Y  yes   yes     yes     yes  2580  2120      8      6  64  32
# 32  TYS938L  yes   yes     yes     yes  2580  2120      8      6  64  32
# 34  TYY453J  yes   yes     yes     yes  2880  2120      6      3  64  32
# 36  UST000T  yes   yes     yes     yes  2580  1980     10      8  64  32
# 37  USZ111S  yes   yes     yes     yes  2440  1980      5      3  48  32
# ...

# %%
#task 2

Px = data['Px_h'] * data['Px_w']
print(Px)
# Out:
# 0      358800
# 1      436800
# 2      604800
# 3     1433600
# 4     1382400
# 5     1382400
# 6     1501200
# 7     6105600
# 8     4953600
# 9     5108400
# 10    4953600
# 11    4953600
# 12    5108400
# 13    6105600
# 14    4331600
# 15    3484800
# 16    5108400
# 17    6105600
# 18    3484800
# 19    6105600
# 20    3484800
# 21    5108400
# 22    1843200
# 23    6105600
# 24    1843200
# 25    5108400
# 26    2534400
# 27    5469600
# 28    5469600
# 29    5469600
# 30    5469600
# 31    5469600
# 32    5469600
# 33    5469600
# 34    6105600
# 35    5172800
# 36    5108400
# 37    4831200
# 38    4953600
# 39    4831200
# 40    5108400
# 41    5108400
# 42    5108400
# 43    5108400
# 44    5108400
# 45    5108400
# 46    5108400
# 47    7257600
# 48    7257600
# 49    7257600
# dtype: int64

# %%
mean_px = Px.mean()
median_px = Px.median()
print(f'Mean of Px: {mean_px}')
print(f'Median of Px: {median_px}')
# Out:
# Mean of Px: 4517184.0
# Median of Px: 5108400.0

# %%
from enum import auto
plt.hist(Px, bins= 'auto')
plt.xlabel('Total Pixels')
plt.ylabel('Frequency')
plt.title('Distribution of Total Pixels')
plt.axvline(mean_px, color='r', linestyle= 'dashed', linewidth=1, label='Mean')
plt.axvline(median_px, color='g', linestyle='dashed', linewidth=1, label='Median')
plt.legend()
plt.show()

# %%
con2 = Px >= median_px
#con2 =Px>=mean_px

# %%
filtered_data_con2 = data[con2]
display(filtered_data_con2)
# Out:
#          PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w   PC  FC  \
# 7    DFR256N  yes    no      no      no  2880  2120      8      6   12   8
# 9    ENG897N  yes   yes     yes     yes  2580  1980      5      3   64  32
# 12   ETT987D   no   yes     yes     yes  2580  1980      6      5   64  32
# 13   NAJ56GL   no   yes     yes      no  2880  2120      6      5   32  16
# 16   PDF768G   no    no     yes     yes  2580  1980      8      6   64  32
# 17   PDG234M   no    no     yes     yes  2880  2120      8      6    8   8
# 19  PNWD777L   no    no     yes     yes  2880  2120      4      3   24  12
# 21   QWR222Y   no   yes     yes     yes  2580  1980      8      6   64  32
# 23   RAY344W   no   yes     yes     yes  2880  2120     10      8    8   4
# 25   SDO555G   no   yes     yes     yes  2580  1980      6      3   64  32
# 27   SFK567Y  yes   yes     yes     yes  2580  2120      8      6   64  16
# ...

# %%
data['Scr_d'] = np.sqrt(data['Scr_h']**2 + data['Scr_w']**2)
print(data['Scr_d'])
# Out:
# 0      3.162278
# 1      2.236068
# 2      2.236068
# 3      5.830952
# 4      5.000000
# 5      5.000000
# 6      6.708204
# 7     10.000000
# 8      6.708204
# 9      5.830952
# 10     6.708204
# 11    10.000000
# 12     7.810250
# 13     7.810250
# 14     5.830952
# 15    12.806248
# 16    10.000000
# 17    10.000000
# 18    10.000000
# 19     5.000000
# 20     5.000000
# 21    10.000000
# 22     5.000000
# 23    12.806248
# 24     7.211103
# 25     6.708204
# 26     5.830952
# 27    10.000000
# 28    10.000000
# 29    10.000000
# 30    10.000000
# 31    10.000000
# 32    10.000000
# 33    10.000000
# 34     6.708204
# 35     5.830952
# 36    12.806248
# 37     5.830952
# 38     5.830952
# 39     7.810250
# 40     5.830952
# 41    10.000000
# 42    10.000000
# 43    10.000000
# 44    12.806248
# 45    10.000000
# 46     5.000000
# 47    10.000000
# 48    10.000000
# 49    10.000000
# Name: Scr_d, dtype: float64

# %%
data['Scr_d'] = np.sqrt(data['Scr_h']**2 + data['Scr_w']**2)
display(data.head())
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
# 2  BAB657J   no   yes      no      no   840   720      2      1   4   2
# 3  BBD456K   no   yes     yes      no  1280  1120      5      3   6   2
# 4  CCP761U   no   yes     yes      no  1280  1080      4      3   6   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price     Scr_d
# 0        8     2800    2      7     320   3297  3.162278
# 1        8     3000    2      7     280   4500  2.236068
# 2        8     3300    2      7     400   4898  2.236068
# 3       32     3000    2      3     300   6900  5.830952
# 4       16     3000    2      3     210   5600  5.000000

# %%
q1_scr_d = data['Scr_d'].quantile(0.25)
q2_scr_d = data['Scr_d'].quantile(0.50)
q3_scr_d = data['Scr_d'].quantile(0.75)

print(f'Q1 of Scr_d: {q1_scr_d}')
print(f'Q2 of Scr_d: {q2_scr_d}')
print(f'Q3 of Scr_d: {q3_scr_d}')
# Out:
# Q1 of Scr_d: 5.830951894845301
# Q2 of Scr_d: 7.810249675906654
# Q3 of Scr_d: 10.0

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Scr_d'], bins='auto', edgecolor='black')
plt.axvline(q1_scr_d, color='r', linestyle='dashed', linewidth=1, label='Q1')
plt.axvline(q2_scr_d, color='g', linestyle='dashed', linewidth=1, label='Median(Q2)')
plt.axvline(q3_scr_d, color='black', linestyle='dashed', linewidth=1, label='Q3')
plt.title('Distribution of Screen Diagonal (Scr_d) with Quartiles')
plt.xlabel('Screen Diagonal (Scr_d)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
con3 = data['Scr_d'] >= q3_scr_d
display(con3.head())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Scr_d, dtype: bool

# %%
filtered_data_con3 = data[con3]
display(filtered_data_con3.head())
# Out:
#         PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 7   DFR256N  yes    no      no      no  2880  2120      8      6  12   8
# 11  ELS333L  yes   yes     yes     yes  2580  1920      8      6  64  32
# 15  NSD450I   no    no     yes     yes  1980  1760     10      8  16  16
# 16  PDF768G   no    no     yes     yes  2580  1980      8      6  64  32
# 17  PDG234M   no    no     yes     yes  2880  2120      8      6   8   8
#
#     Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price      Scr_d
# 7        32     3200    2      3      80  15600  10.000000
# 11        8     4500    8      4     150  43980  10.000000
# 15      128     3900    6      4     180  23456  12.806248
# 16      128     3300    4      3     160  22650  10.000000
# 17       64     2800    4      3     250  19806  10.000000

# %%
# Let's tackle these features: "PC", "FC"
plt.figure(figsize=(10, 6))
plt.hist(data['PC'], bins= 'auto' ,  edgecolor='black', alpha = 0.9, label='PC')
plt.axvline(data['PC'].mean(), color='black', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(data['PC'].median(), color='purple', linestyle='dashed', linewidth=1, label='Median')
plt.title('Distribution of Primary Camera')
plt.xlabel('Primary Camera')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['FC'],  edgecolor='black',  label='FC')
plt.axvline(data['FC'].mean(), color='black', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(data['FC'].median(), color='purple', linestyle='dashed', linewidth=1, label='Median')
plt.title('Distribution of Front Camera')
plt.xlabel('Front Camera')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
median_pc = data['PC'].median()

print(f'Median of PC: {median_pc}')
# Out:
# Median of PC: 40.0

# %%
median_fc = data['FC'].median()
print(f'Median of FC: {median_fc}')
# Out:
# Median of FC: 16.0

# %%
con4 = (data['PC'] >= median_pc) & (data['FC'] >= median_fc)
display(con4.head())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
new=data[con4]
display(new)
# Out:
#         PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w   PC  FC  \
# 9   ENG897N  yes   yes     yes     yes  2580  1980      5      3   64  32
# 11  ELS333L  yes   yes     yes     yes  2580  1920      8      6   64  32
# 12  ETT987D   no   yes     yes     yes  2580  1980      6      5   64  32
# 16  PDF768G   no    no     yes     yes  2580  1980      8      6   64  32
# 21  QWR222Y   no   yes     yes     yes  2580  1980      8      6   64  32
# 25  SDO555G   no   yes     yes     yes  2580  1980      6      3   64  32
# 27  SFK567Y  yes   yes     yes     yes  2580  2120      8      6   64  16
# 28  SSD000L  yes   yes     yes     yes  2580  2120      8      6   64  32
# 29  SYL888P   no   yes     yes     yes  2580  2120      8      6   64  16
# 30  TVF078Y  yes   yes     yes     yes  2580  2120      8      6   64  32
# 32  TYS938L  yes   yes     yes     yes  2580  2120      8      6   64  32
# 33  TYU444Q   no   yes     yes     yes  2580  2120      8      6   64  32
# ...

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Int_Mem'], bins='auto', edgecolor='black')
plt.axvline(data['Int_Mem'].mean(), color='black', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(data['Int_Mem'].median(), color='purple', linestyle='dashed', linewidth=1, label='Median')
plt.title('Distribution of Internal Memory')
plt.xlabel('Internal Memory')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Bty_Pwr'], bins='auto', edgecolor='black')
plt.axvline(data['Bty_Pwr'].mean(), color='black', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(data['Bty_Pwr'].median(), color='purple', linestyle='dashed', linewidth=1, label='Median')
plt.title('Distribution of Battery Power')
plt.xlabel('Battery Power')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['RAM'], bins='auto', edgecolor='black')
plt.axvline(data['RAM'].mean(), color='black', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(data['RAM'].median(), color='purple', linestyle='dashed', linewidth=1, label='Median')
plt.title('Distribution of RAM')
plt.xlabel('RAM')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
mean_int_mem = data['Int_Mem'].mean()
mean_bty_pwr = data['Bty_Pwr'].mean()
mean_ram = data['RAM'].mean()

print(f'Mean of Int_Mem: {mean_int_mem}')
print(f'Mean of Bty_Pwr: {mean_bty_pwr}')
print(f'Mean of RAM: {mean_ram}')
# Out:
# Mean of Int_Mem: 173.76
# Mean of Bty_Pwr: 3740.0
# Mean of RAM: 5.76

# %%
con5 = (data['Int_Mem'] >= mean_int_mem) & (data['Bty_Pwr'] >= mean_bty_pwr) & (data['RAM'] >= mean_ram)

# %%
new=data[con5]
display(new)
# Out:
#         PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w   PC  FC  \
# 28  SSD000L  yes   yes     yes     yes  2580  2120      8      6   64  32
# 29  SYL888P   no   yes     yes     yes  2580  2120      8      6   64  16
# 30  TVF078Y  yes   yes     yes     yes  2580  2120      8      6   64  32
# 32  TYS938L  yes   yes     yes     yes  2580  2120      8      6   64  32
# 42  WZB298K  yes   yes     yes     yes  2580  1980      8      6   64  32
# 44  XTL675G  yes   yes     yes     yes  2580  1980     10      8   64  32
# 47  ZDF789K  yes   yes     yes      no  2880  2520      8      6   64  32
# 48  ZEO567M  yes   yes     yes      no  2880  2520      8      6  128  64
# 49  ZZZ909X  yes   yes     yes      no  2880  2520      8      6  128  64
#
#     Int_Mem  Bty_Pwr  RAM  Depth  Weight   Price      Scr_d
# 28      512     4200    8      3     270   36555  10.000000
# 29      256     5000    8      3     320   32459  10.000000
# ...

# %%
#7
plt.figure(figsize=(10, 6))
plt.hist(data['Depth'], bins='auto', edgecolor='black')
plt.axvline(data['Depth'].mean(), color='black', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(data['Depth'].median(), color='purple', linestyle='dashed', linewidth=1, label='Median')
plt.title('Distribution of depth')
plt.xlabel('Depth')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Weight'], bins='auto', edgecolor='black')
plt.axvline(data['Weight'].mean(), color='black', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(data['Weight'].median(), color='purple', linestyle='dashed', linewidth=1, label='Median')
plt.title('Distribution of Width')
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
mean_depth = data['Depth'].mean()
mean_weight = data['Weight'].mean()


print(f'Mean of depth: {mean_depth}')
print(f'Mean of weight: {mean_weight}')
# Out:
# Mean of depth: 3.44
# Mean of weight: 195.2

# %%
con6 = (data['Depth'] <= mean_depth) & (data['Weight'] <= mean_weight)
new=data[con6]
display(new)
# Out:
#         PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w   PC  FC  \
# 6   CTX123L  yes    no     yes      no  1390  1080      6      3    8   4
# 7   DFR256N  yes    no      no      no  2880  2120      8      6   12   8
# 8   DGS789M  yes   yes     yes     yes  2580  1920      6      3   32  16
# 9   ENG897N  yes   yes     yes     yes  2580  1980      5      3   64  32
# 16  PDF768G   no    no     yes     yes  2580  1980      8      6   64  32
# 20  POP857R   no   yes     yes     yes  1980  1760      4      3   32  16
# 21  QWR222Y   no   yes     yes     yes  2580  1980      8      6   64  32
# 22  QZR577O   no   yes     yes     yes  1440  1280      4      3    8   8
# 23  RAY344W   no   yes     yes     yes  2880  2120     10      8    8   4
# 24  RBZ451D   no   yes     yes     yes  1440  1280      6      4    8   4
# 30  TVF078Y  yes   yes     yes     yes  2580  2120      8      6   64  32
# 31  TYQ109G   no   yes     yes     yes  2580  2120      8      6   32  16
# ...

# %%
df1 = data[con1 & con2 & con3 & con4 & con5 & con6]

# %%
print("Dimensions of the filtered dataframe:")
print(df1.shape)
# Out:
# Dimensions of the filtered dataframe:
# (3, 18)

# %%
df1_sorted_price = df1.sort_values(by='Price')
display(df1_sorted_price)
# Out:
#         PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 30  TVF078Y  yes   yes     yes     yes  2580  2120      8      6  64  32
# 42  WZB298K  yes   yes     yes     yes  2580  1980      8      6  64  32
# 32  TYS938L  yes   yes     yes     yes  2580  2120      8      6  64  32
#
#     Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price  Scr_d
# 30      512     4860    8      3      90  29999   10.0
# 42     1024     5600    8      3     160  39000   10.0
# 32     1024     4860    8      3     120  46777   10.0

# %%
numerical_features = df1.select_dtypes(include=np.number)
deviations = numerical_features.std() / numerical_features.mean()
deviations.name = 'calculated ratio'

# %%
deviations_sorted = deviations.sort_values(ascending=False)
display(deviations_sorted)
# Out:
# Int_Mem    0.346410
# Weight     0.284747
# Price      0.217569
# Bty_Pwr    0.083663
# Px_w       0.038985
# PC         0.000000
# Scr_w      0.000000
# Scr_h      0.000000
# Px_h       0.000000
# RAM        0.000000
# FC         0.000000
# Depth      0.000000
# Scr_d      0.000000
# Name: calculated ratio, dtype: float64
